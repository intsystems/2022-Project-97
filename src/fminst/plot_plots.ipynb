# %%
import torch
import numpy as np
import matplotlib.pylab as plt
from IPython.display import clear_output
import torch.nn as nn 
import torch.optim as optim

import antidistil
import pipeline
import consts
from importlib import reload
import plot
import json
reload(plot)
reload(antidistil)
reload(pipeline)
reload(consts)
plot.prepare_for_plots()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/compat/_optional.py:149: UserWarning: Pandas requires version '1.3.1' or newer of 'bottleneck' (version '1.2.1' currently installed).
#   warnings.warn(msg, UserWarning)
# Using cuda device
# Using cuda device

# %%
#with open(pipeline.get_path()+'/history_antidistil2.json') as inp:
#    history_antidistil = json.load(inp)

with open(pipeline.get_path()+'/history_noise.json') as inp:
    history_noise = json.load(inp)

with open(pipeline.get_path()+'/history_antidistil_scratch.json') as inp:
    history_antidistil_scratch = json.load(inp)

with open(pipeline.get_path()+'/history_no_antidistil.json') as inp:
    history_l1_l3 = json.load(inp)
    

    
with open(pipeline.get_path()+'/history_5_zero.json') as inp:
    history_5_zero = json.loads(inp.read())

with open(pipeline.get_path()+'/history_5_scratch.json') as inp:
    history_5_scratch = json.loads(inp.read())
    
with open(pipeline.get_path()+'/history_5_n2n.json') as inp:
    history_5_n2n = json.loads(inp.read())

# %%
reload(plot)
plot.prepare_for_plots()
plot.plot_variance([history_noise, history_l1_l3, history_antidistil_scratch, history_5_zero, 
                   history_5_scratch, history_5_n2n],
                   np.arange(1, consts.student_5_training_epochs + 1),
                   ['L3', 'L1+L3', 'Antidistillation', 'Zero', 'Scratch', 'Net2Net'], 'val_acc', 
                    'Epoch', 'Accuracy')

# %%
reload(plot)
plot.prepare_for_plots()
plot.plot_variance([history_noise, history_l1_l3, history_antidistil_scratch, 
                   history_5_zero, 
                   history_5_scratch, history_5_n2n],
                   consts.fsgm_eps,
                   ['L3', 'L1+L3', 'Antidistillation', 'Zero', 'Scratch', 'Net2Net'], 'fsgm_noise_acc', 
                    'FSGM eps', 'Accuracy')

# %%
reload(plot)
plot.prepare_for_plots()
plot.plot_variance([history_noise, history_l1_l3, history_antidistil_scratch, history_5_zero, 
                   history_5_scratch, history_5_n2n],
                   consts.fsgm_eps,
                   ['L3', 'L1+L3', 'Antidistillation', 'Zero', 'Scratch', 'Net2Net'], 'param_noise_acc', 
                    'Param noise eps', 'Accuracy')
