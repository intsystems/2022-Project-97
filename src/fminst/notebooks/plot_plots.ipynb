# %%
import torch
import numpy as np
import matplotlib.pylab as plt
from IPython.display import clear_output
import torch.nn as nn 
import torch.optim as optim

import antidistil
import pipeline
import consts
from importlib import reload
import plot
import json
reload(plot)
reload(antidistil)
reload(pipeline)
reload(consts)
plot.prepare_for_plots()
# Out:
# Using cpu device
# Using cpu device

# %%
with open(pipeline.get_path()+'/history_noise.json') as inp:
    history_noise = json.load(inp)

with open(pipeline.get_path()+'/history_antidistil.json') as inp:
    history_antidistil = json.load(inp)

with open(pipeline.get_path()+'/history_best_antidistill.json') as inp:
    history_best_antidistil = json.load(inp)

with open(pipeline.get_path()+'/history_l1_l3.json') as inp:
    history_l1_l3 = json.load(inp)
    

    
with open(pipeline.get_path()+'/history_5_zero.json') as inp:
    history_5_zero = json.loads(inp.read())

with open(pipeline.get_path()+'/history_5_uni.json') as inp:
    history_5_uni = json.loads(inp.read())

with open(pipeline.get_path()+'/history_5_scratch.json') as inp:
    history_5_scratch = json.loads(inp.read())
    
with open(pipeline.get_path()+'/history_5_n2n.json') as inp:
    history_5_n2n = json.loads(inp.read())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
reload(plot)
plot.prepare_for_plots()
plot.plot_variance([history_noise, history_l1_l3, history_antidistil, history_5_zero, 
                    history_5_uni, history_5_scratch, history_5_n2n, history_best_antidistil],
                   np.arange(1, consts.student_5_training_epochs + 1),
                   ['L3', 'L1+L3', 'Antidistillation', 'Zero',  'Uniform' ,'Scratch', 'Net2Net', 'Best Antidistillation'], 'val_acc', 
                    'Epoch', 'Accuracy')

# %%
reload(plot)
plot.prepare_for_plots()
plot.plot_variance([history_antidistil, history_best_antidistil],
                   np.arange(1, consts.student_5_training_epochs + 1),
                   ['Antidistillation', 'Best Antidistillation'], 'val_acc', 
                    'Epoch', 'Accuracy')

# %%
reload(plot)
plot.prepare_for_plots()
plot.plot_variance([history_noise, history_l1_l3, history_antidistil, 
                   history_5_zero, history_5_uni,
                   history_5_scratch, history_5_n2n, history_best_antidistil],
                   consts.fsgm_eps,
                   ['L3', 'L1+L3', 'Antidistillation', 'Zero', 'Uniform', 'Scratch', 'Net2Net', 'Best Antidistillation'], 'fsgm_noise_acc', 
                    'FSGM eps', 'Accuracy')

# %%
reload(plot)
plot.prepare_for_plots()
plot.plot_variance([history_antidistil, history_best_antidistil],
                   consts.fsgm_eps,
                   ['Antidistillation', 'Best Antidistillation'], 'fsgm_noise_acc', 
                    'FSGM eps', 'Accuracy')

# %%
reload(plot)
plot.prepare_for_plots()
plot.plot_variance([history_noise, history_l1_l3, history_antidistil, history_5_zero, 
                    history_5_uni, history_5_scratch, history_5_n2n, history_best_antidistil],
                   consts.fsgm_eps,
                   ['L3', 'L1+L3', 'Antidistillation', 'Zero', 'Uniform', 'Scratch', 'Net2Net', 'Best Antidistillation'], 'param_noise_acc', 
                    'Param noise eps', 'Accuracy')

# %%
reload(plot)
plot.prepare_for_plots()
plot.plot_variance([history_antidistil, history_best_antidistil],
                   consts.fsgm_eps,
                   ['Antidistillation', 'Best Antidistillation'], 'param_noise_acc', 
                    'Param noise eps', 'Accuracy')
