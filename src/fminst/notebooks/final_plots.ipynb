# %%
import torch
import numpy as np
import matplotlib.pylab as plt
from IPython.display import clear_output
import torch.nn as nn 
import json 

import pipeline
import consts
import plot
plot.prepare_for_plots()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/compat/_optional.py:149: UserWarning: Pandas requires version '1.3.1' or newer of 'bottleneck' (version '1.2.1' currently installed).
#   warnings.warn(msg, UserWarning)
# Using cuda device

# %%
with open(pipeline.get_path()+'/history_full_zero.json') as inp:
    history_full_zero = json.loads(inp.read())
with open(pipeline.get_path()+'/history_5_zero.json') as inp:
    history_5_zero = json.loads(inp.read())

with open(pipeline.get_path()+'/history_full_scratch.json') as inp:
    history_full_scratch = json.loads(inp.read())
with open(pipeline.get_path()+'/history_5_scratch.json') as inp:
    history_5_scratch = json.loads(inp.read())
    
with open(pipeline.get_path()+'/history_full_n2n.json') as inp:
    history_full_n2n = json.loads(inp.read())
with open(pipeline.get_path()+'/history_5_n2n.json') as inp:
    history_5_n2n = json.loads(inp.read())

# %% [markdown]
# # Plots for distilling from full-class teachers

# %%
plot.prepare_for_plots()
plot.plot_variance([history_full_scratch, history_full_zero, history_full_n2n], 
                   np.arange(1, consts.full_teacher_training_epochs+1),
                   ['From scratch', 'Zero', 'N2N'], 'val_acc', 
                    'Epoch', 'Accuracy', 'full_acc')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plot.prepare_for_plots()
plot.plot_variance([history_full_scratch, history_full_zero, history_full_n2n], 
                   consts.fsgm_eps,
                   ['From scratch', 'Zero', 'N2N'], 'fsgm_noise_acc', 
                    'FSGM eps', 'Accuracy', 'full_fsgm_acc')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plot.prepare_for_plots()
plot.plot_variance([history_full_scratch, history_full_zero, history_full_n2n], 
                   consts.noise_eps,
                   ['From scratch', 'Zero', 'N2N'], 'param_noise_acc', 
                    'Noise eps', 'Accuracy', 'full_noise_acc')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Plots for distilling from 5-class teachers

# %%
plot.prepare_for_plots()
plot.plot_variance([history_5_scratch, history_5_zero, history_5_n2n], 
                   np.arange(1, consts.teacher_5_training_epochs+1),
                   ['From scratch', 'Zero', 'N2N'], 'val_acc', 
                    'Epoch', 'Accuracy', '5_acc')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plot.prepare_for_plots()
plot.plot_variance([history_5_scratch, history_5_zero, history_5_n2n], 
                   consts.fsgm_eps,
                   ['From scratch', 'Zero', 'N2N'], 'fsgm_noise_acc', 
                    'FSGM eps', 'Accuracy', '5_fsgm_acc')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plot.prepare_for_plots()
plot.plot_variance([history_5_scratch, history_5_zero, history_5_n2n], 
                   consts.noise_eps,
                   ['From scratch', 'Zero', 'N2N'], 'param_noise_acc', 
                    'Noise eps', 'Accuracy', '5_noise_acc')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
